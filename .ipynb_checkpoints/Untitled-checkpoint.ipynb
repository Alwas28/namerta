# %%
luas = -3 
print(abs(luas))
# Out:
# 3

# %%
luas = abs(-3) 
print(luas)
# Out:
# 3

# %%
panjang = "20" #string
lebar = 10
luas = int(panjang) * lebar
print(luas)
# Out:
# 200

# %%
panjang = int("20") #string
lebar = 10
luas = panjang * lebar
print(luas)
